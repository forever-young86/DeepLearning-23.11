# %% [markdown]
# ## 신경망 모델
# #### - 이진 분류: 유방암 예측 사례

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# - 데이터 준비

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
cancer = load_breast_cancer()
cancer.data.shape
# Out:
# (569, 30)

# %%
cancer_std = StandardScaler().fit_transform(cancer.data)

# %% [markdown]
# #### 1. 데이터를 정규/표준화 하지 않은 경우

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, test_size=0.2, random_state=2023
)

# %% [markdown]
# - 모델 정의

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense       # Fully Connected Network

# %%
model = Sequential([
    Dense(100, input_dim=30, activation='relu'), # 입력층 =>노드의 갯수, 30차원으로 두겠다(feature가 30개이므로), 활성화함수
    Dense(24, activation='relu'),           # 은닉층
    Dense(1, activation='sigmoid')          # 출력층 (이진분류이므로 노드가 1)
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_2 (Dense)             (None, 100)               3100
#
#  dense_3 (Dense)             (None, 24)                2424
#
#  dense_4 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 5549 (21.68 KB)
# Trainable params: 5549 (21.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# - 모델 설정(컴파일)

# %%
model.compile(
    optimizer='adam', 
    loss='binary_crossentropy',  # 손실함수 (이진분류이므로 binary_crossentropy 쓴다)
    metrics=['accuracy']         # 평가
)

# %% [markdown]
# - 모델 학습

# %%
history = model.fit(X_train, y_train,           # history: 학습한 내용을 시각화하기 위한것!
                    validation_split=0.2,       # 학습 중 검증용으로 데이터를 20%를 사용하겠다
                    epochs=100,                 # 반복 횟수
                    batch_size=100)             # 동시에 몇개의 데이터를 메모리에 로드하는가
# 결과는 accuracy 와 val_loss 값을 보고 판단한다!
# Out:
# Epoch 1/100
# 4/4 [==============================] - 1s 78ms/step - loss: 54.5422 - accuracy: 0.6401 - val_loss: 17.4824 - val_accuracy: 0.5824
# Epoch 2/100
# 4/4 [==============================] - 0s 13ms/step - loss: 10.4240 - accuracy: 0.5275 - val_loss: 18.4283 - val_accuracy: 0.4286
# Epoch 3/100
# 4/4 [==============================] - 0s 13ms/step - loss: 19.0514 - accuracy: 0.3599 - val_loss: 12.3382 - val_accuracy: 0.4286
# Epoch 4/100
# 4/4 [==============================] - 0s 12ms/step - loss: 6.8567 - accuracy: 0.4478 - val_loss: 5.1005 - val_accuracy: 0.6703
# Epoch 5/100
# 4/4 [==============================] - 0s 13ms/step - loss: 6.7222 - accuracy: 0.7033 - val_loss: 7.1408 - val_accuracy: 0.6703
# Epoch 6/100
# 4/4 [==============================] - 0s 13ms/step - loss: 3.5028 - accuracy: 0.7830 - val_loss: 1.1996 - val_accuracy: 0.7253
# Epoch 7/100
# 4/4 [==============================] - 0s 13ms/step - loss: 2.8908 - accuracy: 0.5110 - val_loss: 3.2543 - val_accuracy: 0.5385
# Epoch 8/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.9382 - accuracy: 0.6758 - val_loss: 0.5000 - val_accuracy: 0.8791
# Epoch 9/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.8353 - accuracy: 0.8571 - val_loss: 1.2501 - val_accuracy: 0.8462
# Epoch 10/100
# 4/4 [==============================] - 0s 13ms/step - loss: 1.5926 - accuracy: 0.8654 - val_loss: 0.3968 - val_accuracy: 0.8681
# Epoch 11/100
# 4/4 [==============================] - 0s 12ms/step - loss: 1.
100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2563 - accuracy: 0.9066 - val_loss: 0.2422 - val_accuracy: 0.9121
# Epoch 36/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2570 - accuracy: 0.8984 - val_loss: 0.2137 - val_accuracy: 0.9231
# Epoch 37/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2582 - accuracy: 0.9038 - val_loss: 0.2187 - val_accuracy: 0.9231
# Epoch 38/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2549 - accuracy: 0.9038 - val_loss: 0.2445 - val_accuracy: 0.9121
# Epoch 39/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2404 - accuracy: 0.8984 - val_loss: 0.2123 - val_accuracy: 0.9231
# Epoch 40/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2514 - accuracy: 0.9093 - val_loss: 0.2678 - val_accuracy: 0.9011
# Epoch 41/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2407 - accuracy: 0.9066 - val_loss: 0.2188 - val_accuracy: 0.9231
# Epoch 42/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2699 - accuracy: 0.9093 - val_loss: 0.2741 - val_accuracy: 0.9011
# Epoch 43/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2418 - accuracy: 0.9066 - val_loss: 0.2076 - val_accuracy: 0.9121
# Epoch 44/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2306 - accuracy: 0.9121 - val_loss: 0.3218 - val_accuracy: 0.8571
# Epoch 45/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2735 - accuracy: 0.9011 - val_loss: 0.2066 - val_accuracy: 0.9231
# Epoch 46/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2457 - accuracy: 0.8984 - val_loss: 0.2058 - val_accuracy: 0.9231
# Epoch 47/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2252 - accuracy: 0.9121 - val_loss: 0.2116 - val_accuracy: 0.9231
# Epoch 48/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2242 - accuracy: 0.9038 - val_loss: 0.2149 - val_accuracy: 0.9231
# Epoch 49/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2256 - accuracy: 0.9093 - val_loss: 0.2148 - val_accuracy: 0.9231
# Epoch 50/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2194 - accuracy: 0.9066 - val_loss: 0.1994 - val_accuracy: 0.9231
# Epoch 51/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2370 - accuracy: 0.9203 - val_loss: 0.2367 - val_accuracy: 0.9121
# Epoch 52/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2242 - accuracy: 0.9011 - val_loss: 0.2124 - val_accuracy: 0.9341
# Epoch 53/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2279 - accuracy: 0.9203 - val_loss: 0.2712 - val_accuracy: 0.9121
# Epoch 54/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2263 - accuracy: 0.9121 - val_loss: 0.1968 - val_accuracy: 0.9231
# Epoch 55/100
# 4/4 [==============================] - 0s 28ms/step - loss: 0.2300 - accuracy: 0.9038 - val_loss: 0.1946 - val_accuracy: 0.9231
# Epoch 56/100
# 4/4 [==============================] - 0s 13ms/step - loss: 0.2436 - accuracy: 0.9011 - val_loss: 0.2946 - val_accuracy: 0.8901
# Epoch 57/100
# 4/4 [==============================] - 0s 10ms/step - loss: 0.2590 - accuracy: 0.8984 - val_loss: 0.2233 - val_accuracy: 0.9231
# Epoch 58/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2531 - accuracy: 0.9066 - val_loss: 0.2111 - val_accuracy: 0.9231
# Epoch 59/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.2212 - accuracy: 0.9093 - val_loss: 0.1936 - val_accuracy: 0.9231
# Epoch 60/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2563 - accuracy: 0.9038 - val_loss: 0.1853 - val_accuracy: 0.9231
# Epoch 61/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2082 - accuracy: 0.9148 - val_loss: 0.1927 - val_accuracy: 0.9231
# Epoch 62/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.2108 - accuracy: 0.9093 - val_loss: 0.1990 - val_accuracy: 0.9231
# Epoch 63/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.
100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1678 - accuracy: 0.9231 - val_loss: 0.1595 - val_accuracy: 0.9231
# Epoch 92/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1701 - accuracy: 0.9341 - val_loss: 0.1798 - val_accuracy: 0.9341
# Epoch 93/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1801 - accuracy: 0.9231 - val_loss: 0.1702 - val_accuracy: 0.9341
# Epoch 94/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1867 - accuracy: 0.9258 - val_loss: 0.1603 - val_accuracy: 0.9231
# Epoch 95/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1693 - accuracy: 0.9313 - val_loss: 0.1607 - val_accuracy: 0.9341
# Epoch 96/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1786 - accuracy: 0.9176 - val_loss: 0.1564 - val_accuracy: 0.9231
# Epoch 97/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1818 - accuracy: 0.9231 - val_loss: 0.2136 - val_accuracy: 0.9341
# Epoch 98/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1846 - accuracy: 0.9258 - val_loss: 0.1633 - val_accuracy: 0.9341
# Epoch 99/100
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1899 - accuracy: 0.9286 - val_loss: 0.1604 - val_accuracy: 0.9341
# Epoch 100/100
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1708 - accuracy: 0.9231 - val_loss: 0.2330 - val_accuracy: 0.9231

# %% [markdown]
# - 모델 평가

# %%
model.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2299 - accuracy: 0.8947
# [0.22991329431533813, 0.8947368264198303]

# %% [markdown]
# - 훈련과정 시각화
#     - epoch에 따른 accuracy, val_loss의 변화

# %%
y_acc = history.history['accuracy']
y_vloss = history.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,6))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1]), plt.xlabel('Epoch')
plt.title('No feature transformation')
plt.show()

# %% [markdown]
# #### 2. 데이터를 표준화한 경우

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(
    cancer_std, cancer.target, stratify=cancer.target, test_size=0.2, random_state=2023
)

# %%
# 모델 정의
model2 = Sequential()
model2.add(Dense(100, input_shape=(30,), activation='relu'))    # 입력
model2.add(Dense(24, activation='relu'))        # 은닉
model2.add(Dense(1, activation='sigmoid'))      # 출력
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_5 (Dense)             (None, 100)               3100
#
#  dense_6 (Dense)             (None, 24)                2424
#
#  dense_7 (Dense)             (None, 1)                 25
#
# =================================================================
# Total params: 5549 (21.68 KB)
# Trainable params: 5549 (21.68 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 모델 컴파일
model2.compile('adam', 'binary_crossentropy', metrics=['accuracy'])

# %%
# 모델 학습
history2 = model2.fit(X_train2, y_train2, validation_split=0.2, epochs=100, batch_size=100, verbose=0)

# %%
# 모델 평가
model2.evaluate(X_test2, y_test2)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2649 - accuracy: 0.9474
# [0.26488879323005676, 0.9473684430122375]

# %%
# 학습과정 시각화
y_acc2 = history2.history['accuracy']
y_vloss2 = history2.history['val_loss']

plt.figure(figsize=(12,7))
plt.plot(xs, y_acc2, label='train accuracy')
plt.plot(xs, y_vloss2, label='validation loss')
plt.legend(), plt.grid()
plt.ylim([0,1.1]), plt.xlabel('Epoch')
plt.title('With feature transformation')
plt.show()
